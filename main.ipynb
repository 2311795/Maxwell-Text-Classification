# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 🔤 Maxwell Text Classification – Starter Notebook\n",
    "This notebook clones the project, installs dependencies, and runs an example script.\n",
    "\n",
    "Feel free to modify the script you want to run."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ✅ Clone the GitHub repository\n",
    "!git clone https://github.com/2311795/Maxwell-Text-Classification.git\n",
    "%cd Maxwell-Text-Classification"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ✅ Install dependencies\n",
    "!pip install -r requirements.txt"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# ✅ Run one of the scripts (example)\n",
    "!python 'Matrix Response/matrix_script1.py'"
   ]
  }
 ],
 "metadata": {
  "colab": {
   "name": "main.ipynb",
   "provenance": []
  },
  "kernelspec": {
   "display_name": "Python 3",
   "language": "python",
   "name": "python3"
  },
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}

# %%
[![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/2311795/Maxwell-Text-Classification/blob/main/main.ipynb)
# Out:
#   Cell In[1], line 1
#     [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/2311795/Maxwell-Text-Classification/blob/main/main.ipynb)
#      ^
# SyntaxError: invalid syntax

# %%
# 📌 Cell 2: Install required packages
# !pip install -r requirements.txt
# Out:
# Collecting en-core-web-sm@ https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl#sha256=86cc141f63942d4b2c5fcee06630fd6f904788d2f0ab005cce45aadb8fb73889 (from -r requirements.txt (line 19))
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 640.0 kB/s eta 0:00:20
#      --------------------------------------- 0.1/12.8 MB 812.7 kB/s eta 0:00:16
#      - -------------------------------------- 0.6/12.8 MB 6.6 MB/s eta 0:00:02
#      ------- -------------------------------- 2.4/12.8 MB 19.3 MB/s eta 0:00:01
#      ------------------ --------------------- 6.0/12.8 MB 32.1 MB/s eta 0:00:01
#      --------------------------- ------------ 8.6/12.8 MB 39.4 MB/s eta 0:00:01
#      ---------------------------------- ---- 11.2/12.8 MB 65.2 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 65.6 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: absl-py==2.1.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: annotated-types==0.6.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: asttokens==2.4.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 3)) (2.4.1)
# Requirement already satisfied: astunparse==1.6.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 4)) (1.6.3)
# Requirement already satisfied: blis==0.7.11 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 5)) (0.7.11)
# Requirement already satisfied: catalogue==2.0.10 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 6)) (2.0.10)
# Requirement already satisfied: certifi==2024.2.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 7)) (2024.2.2)
# Requirement already satisfied: charset-normalizer==3.3.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 8)) (3.3.2)
# Requirement already satisfied: click==8.1.7 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 9)) (8.1.7)
# Requirement already satisfied: cloudpathlib==0.16.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: colorama==0.4.6 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 11)) (0.4.6)
# Requirement already satisfied: comm==0.2.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 12)) (0.2.2)
# Requirement already satisfied: confection==0.1.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 13)) (0.1.4)
# Requirement already satisfied: contourpy==1.2.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 14)) (1.2.1)
# Requirement already satisfied: cycler==0.12.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 15)) (0.12.1)
# Requirement already satisfied: cymem==2.0.8 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 16)) (2.0.8)
# Requirement already satisfied: debugpy==1.8.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 17)) (1.8.1)
# Requirement already satisfied: decorator==5.1.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 18)) (5.1.1)
# Requirement already satisfied: executing==2.0.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 20)) (2.0.1)
# Requirement already satisfied: filelock==3.15.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 21)) (3.15.1)
# Requirement already satisfied: flatbuffers==24.3.25 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 22)) (24.3.25)
# Requirement already satisfied: fonttools==4.51.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 23)) (4.51.0)
# Requirement already satisfied: fsspec==2024.6.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 24)) (2024.6.0)
# Requirement already satisfied: gast==0.5.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 25)) (0.5.4)
# Requirement already satisfied: google-pasta==0.2.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 26)) (0.2.0)
# Requirement already satisfied: greenlet==3.1.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 27)) (3.1.1)
# Requirement already satisfied: grpcio==1.64.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 28)) (1.64.1)
# Requirement already satisfied: h5py==3.11.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 29)) (3.11.0)
# Requirement already satisfied: huggingface-hub==0.23.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 30)) (0.23.4)
# Requirement already satisfied: idna==3.7 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 31)) (3.7)
# Requirement already satisfied: imbalanced-learn==0.13.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 32)) (0.13.0)
# Requirement already satisfied: intel-openmp==2021.4.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 33)) (2021.4.0)
# Requirement already satisfied: ipykernel==6.29.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 34)) (6.29.4)
# Requirement already satisfied: ipython==8.24.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 35)) (8.24.0)
# Requirement already satisfied: jedi==0.19.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 36)) (0.19.1)
# Requirement already satisfied: Jinja2==3.1.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 37)) (3.1.3)
# Requirement already satisfied: joblib==1.4.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 38)) (1.4.2)
# Requirement already satisfied: jupyter_client==8.6.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 39)) (8.6.1)
# Requirement already satisfied: jupyter_core==5.7.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 40)) (5.7.2)
# Requirement already satisfied: keras==3.3.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 41)) (3.3.3)
# Requirement already satisfied: kiwisolver==1.4.5 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 42)) (1.4.5)
# Requirement already satisfied: langcodes==3.4.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 43)) (3.4.0)
# Requirement already satisfied: language_data==1.2.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 44)) (1.2.0)
# Requirement already satisfied: libclang==18.1.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 45)) (18.1.1)
# Requirement already satisfied: marisa-trie==1.1.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 46)) (1.1.0)
# Requirement already satisfied: Markdown==3.6 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 47)) (3.6)
# Requirement already satisfied: markdown-it-py==3.0.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 48)) (3.0.0)
# Requirement already satisfied: MarkupSafe==2.1.5 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 49)) (2.1.5)
# Requirement already satisfied: matplotlib==3.8.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 50)) (3.8.4)
# Requirement already satisfied: matplotlib-inline==0.1.7 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 51)) (0.1.7)
# Requirement already satisfied: mdurl==0.1.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 52)) (0.1.2)
# Requirement already satisfied: mkl==2021.4.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 53)) (2021.4.0)
# Requirement already satisfied: ml-dtypes==0.3.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 54)) (0.3.2)
# Requirement already satisfied: mpmath==1.3.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 55)) (1.3.0)
# Requirement already satisfied: murmurhash==1.0.10 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 56)) (1.0.10)
# Requirement already satisfied: namex==0.0.8 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 57)) (0.0.8)
# Requirement already satisfied: nest-asyncio==1.6.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 58)) (1.6.0)
# Requirement already satisfied: networkx==3.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 59)) (3.3)
# Requirement already satisfied: nltk==3.8.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 60)) (3.8.1)
# Requirement already satisfied: numpy==1.26.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 61)) (1.26.4)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 62)) (3.3.0)
# Requirement already satisfied: optree==0.11.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 63)) (0.11.0)
# Requirement already satisfied: packaging==24.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 64)) (24.0)
# Requirement already satisfied: pandas==2.2.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 65)) (2.2.2)
# Requirement already satisfied: parso==0.8.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 66)) (0.8.4)
# Requirement already satisfied: pillow==10.3.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 67)) (10.3.0)
# Requirement already satisfied: platformdirs==4.2.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 68)) (4.2.1)
# Requirement already satisfied: preshed==3.0.9 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 69)) (3.0.9)
# Requirement already satisfied: prompt-toolkit==3.0.43 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 70)) (3.0.43)
# Requirement already satisfied: protobuf==4.25.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 71)) (4.25.3)
# Requirement already satisfied: psutil==5.9.8 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 72)) (5.9.8)
# Requirement already satisfied: pure-eval==0.2.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 73)) (0.2.2)
# Requirement already satisfied: pydantic==2.7.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 74)) (2.7.1)
# Requirement already satisfied: pydantic_core==2.18.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 75)) (2.18.2)
# Requirement already satisfied: Pygments==2.17.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 76)) (2.17.2)
# Requirement already satisfied: pyodbc==5.2.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 77)) (5.2.0)
# Requirement already satisfied: pyparsing==3.1.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 78)) (3.1.2)
# Requirement already satisfied: python-dateutil==2.9.0.post0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 79)) (2.9.0.post0)
# Requirement already satisfied: pytz==2024.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 80)) (2024.1)
# Requirement already satisfied: pywin32==306 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 81)) (306)
# Requirement already satisfied: PyYAML==6.0.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 82)) (6.0.1)
# Requirement already satisfied: pyzmq==26.0.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 83)) (26.0.2)
# Requirement already satisfied: regex==2024.5.15 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 84)) (2024.5.15)
# Requirement already satisfied: requests==2.31.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 85)) (2.31.0)
# Requirement already satisfied: rich==13.7.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 86)) (13.7.1)
# Requirement already satisfied: safetensors==0.4.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 87)) (0.4.3)
# Requirement already satisfied: scikit-learn==1.5.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 88)) (1.5.0)
# Requirement already satisfied: scipy==1.13.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 89)) (1.13.1)
# Requirement already satisfied: seaborn==0.13.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 90)) (0.13.2)
# Requirement already satisfied: setuptools==69.5.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 91)) (69.5.1)
# Requirement already satisfied: six==1.16.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 92)) (1.16.0)
# Requirement already satisfied: sklearn-compat==0.1.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 93)) (0.1.3)
# Requirement already satisfied: smart-open==6.4.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 94)) (6.4.0)
# Requirement already satisfied: spacy==3.7.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 95)) (3.7.4)
# Requirement already satisfied: spacy-legacy==3.0.12 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 96)) (3.0.12)
# Requirement already satisfied: spacy-loggers==1.0.5 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 97)) (1.0.5)
# Requirement already satisfied: SQLAlchemy==2.0.38 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 98)) (2.0.38)
# Requirement already satisfied: srsly==2.4.8 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 99)) (2.4.8)
# Requirement already satisfied: stack-data==0.6.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 100)) (0.6.3)
# Requirement already satisfied: sympy==1.12.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 101)) (1.12.1)
# Requirement already satisfied: tbb==2021.12.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 102)) (2021.12.0)
# Requirement already satisfied: tensorboard==2.16.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 103)) (2.16.2)
# Requirement already satisfied: tensorboard-data-server==0.7.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 104)) (0.7.2)
# Requirement already satisfied: tensorflow==2.16.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 105)) (2.16.1)
# Requirement already satisfied: tensorflow-intel==2.16.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 106)) (2.16.1)
# Requirement already satisfied: termcolor==2.4.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 107)) (2.4.0)
# Requirement already satisfied: tf_keras==2.16.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 108)) (2.16.0)
# Requirement already satisfied: thinc==8.2.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 109)) (8.2.3)
# Requirement already satisfied: threadpoolctl==3.5.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 110)) (3.5.0)
# Requirement already satisfied: tokenizers==0.19.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 111)) (0.19.1)
# Requirement already satisfied: torch==2.3.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 112)) (2.3.1)
# Requirement already satisfied: tornado==6.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 113)) (6.4)
# Requirement already satisfied: tqdm==4.66.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 114)) (4.66.2)
# Requirement already satisfied: traitlets==5.14.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 115)) (5.14.3)
# Requirement already satisfied: transformers==4.41.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 116)) (4.41.2)
# Requirement already satisfied: typer==0.9.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 117)) (0.9.4)
# Requirement already satisfied: typing_extensions==4.11.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 118)) (4.11.0)
# Requirement already satisfied: tzdata==2024.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 119)) (2024.1)
# Requirement already satisfied: urllib3==2.2.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 120)) (2.2.1)
# Requirement already satisfied: wasabi==1.1.2 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 121)) (1.1.2)
# Requirement already satisfied: wcwidth==0.2.13 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 122)) (0.2.13)
# Requirement already satisfied: weasel==0.3.4 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 123)) (0.3.4)
# Requirement already satisfied: Werkzeug==3.0.3 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 124)) (3.0.3)
# Requirement already satisfied: wheel==0.43.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 125)) (0.43.0)
# Requirement already satisfied: wrapt==1.16.0 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 126)) (1.16.0)
# Requirement already satisfied: xgboost==2.1.1 in c:\users\nosao\desktop\spacyproj\spacy_venv\lib\site-packages (from -r requirements.txt (line 127)) (2.1.1)
#
# The conflict is caused by:
#     The user requested numpy==1.26.4
#     The user requested numpy==2.0.2
#
# To fix this you could try to:
# 1. loosen the range of package versions you've specified
# 2. remove package versions to allow pip attempt to solve the dependency conflict
# ERROR: Cannot install numpy==1.26.4 and numpy==2.0.2 because these package versions have conflicting dependencies.
# ERROR: ResolutionImpossible: for help visit https://pip.pypa.io/en/latest/topics/dependency-resolution/#dealing-with-dependency-conflicts
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 📌 Cell 3: Dropdown to select and run a script
import ipywidgets as widgets
from IPython.display import display

# List of available scripts
scripts = [
    "Matrix Response/matrix_script1.py",
    "Matrix Response/matrix_script2.py",
    "Single Response/single_script1.py",
    "Single Response/single_script2.py",
    "Target Response/target_script1.py",
    "Target Response/target_script2.py"
]

dropdown = widgets.Dropdown(
    options=scripts,
    description='Run Script:',
    layout=widgets.Layout(width='70%')
)

run_button = widgets.Button(description="▶️ Run", button_style="success")

output = widgets.Output()

def run_script(b):
    with output:
        output.clear_output()
        print(f"Running {dropdown.value}...\n")
        # !python "{dropdown.value}"

run_button.on_click(run_script)

display(dropdown, run_button, output)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # 📌 Cell 3: Dropdown to select and run a script
# ----> 2 import ipywidgets as widgets
#       3 from IPython.display import display
#       5 # List of available scripts
#
# ModuleNotFoundError: No module named 'ipywidgets'
