# %%
# JUPYTER NOTEBOOK CELL: HERA Communication Element (Questions 1–6) with Rule-Based Labeling

import pandas as pd

# 1. Load the dataset
df = pd.read_csv("C:/Users/nosao/Desktop/Maxwell-Text Classification/Linear Response/data/linear_communication.csv")

# Convert columns to a consistent lowercase/strip to avoid accidental mismatches
df.columns = df.columns.str.strip().str.lower()

# Print out columns to verify
print("Available columns:", df.columns.tolist())

# 2. Define a rule-based function that assigns a label (A, B, or C) for each HERA Communication question
def label_hera_communication(description):
    """
    A placeholder, naive example of how to generate labels (A, B, or C) for
    HERA Communication Questions 1 through 6. Modify as needed to reflect
    actual criteria from your HERA documentation.
    """
    # Convert to lowercase for easy keyword matching
    text = description.lower() if isinstance(description, str) else ""

    # QUESTION 1: "straightforward information in a clear and accurate manner"
    # Example logic: if 'straightforward' or 'basic' is found, label B, else A
    if "straightforward" in text or "basic" in text:
        q1_label = "B"
    else:
        q1_label = "A"

    # QUESTION 2: "information which needs careful explanation/interpretation"
    # Example logic: if 'interpretation' or 'explain' is found, label B, else A
    if "interpretation" in text or "explain" in text:
        q2_label = "B"
    else:
        q2_label = "A"

    # QUESTION 3: "complex conceptual ideas/technical info"
    # Example logic: if 'complex' or 'technical' is found, label C, else A
    if "complex" in text or "technical" in text:
        q3_label = "C"
    else:
        q3_label = "A"

    # QUESTION 4: "straightforward information in an accurate manner (again) but different examples"
    # Example logic: if 'recording' or 'minute taking' is found, label B, else A
    if "recording" in text or "minute taking" in text:
        q4_label = "B"
    else:
        q4_label = "A"

    # QUESTION 5: "info needing explanation to help others understand in formal contexts"
    # Example logic: if 'training' or 'formal' is found, label B, else A
    if "training" in text or "formal" in text:
        q5_label = "B"
    else:
        q5_label = "A"

    # QUESTION 6: "complex conceptual info that may be highly detailed or technical"
    # Example logic: if 'research' or 'specialist' is found, label C, else A
    if "research" in text or "specialist" in text:
        q6_label = "C"
    else:
        q6_label = "A"

    return {
        "Q1_label": q1_label,
        "Q2_label": q2_label,
        "Q3_label": q3_label,
        "Q4_label": q4_label,
        "Q5_label": q5_label,
        "Q6_label": q6_label
    }

# 3. Apply the labeling function to each row's job description
#    We assume your dataset has a column named "job description"
if 'job description' not in df.columns:
    raise ValueError("The dataset must have a column named 'job description'.")

df_labels = df['job description'].apply(label_hera_communication).apply(pd.Series)

# 4. Concatenate the new columns (Q1_label through Q6_label) with the original DataFrame
df_final = pd.concat([df, df_labels], axis=1)

# 5. Print or save the final DataFrame
print("Labeled Data:")
print(df_final)

# Optional: Save to CSV if desired
# df_final.to_csv("data_new_labeled.csv", index=False)

# 6. Define a helper function to label a *new* job description
def predict_new_job_description(description):
    labels = label_hera_communication(description)
    print("Predicted labels for the new job description:")
    for qnum, lab in labels.items():
        print(f"{qnum}: {lab}")

# Example usage with a new job description snippet
new_job_desc = """
Purpose of the Role: To provide of an effective Joinery resource to ensure the University 
fabric is efficiently maintained on a day-to-day basis including undertaking Project works. To 
ensure the effective interaction of Estate and Facilities services with other services.
Responsible to: Estates Team Leader
Main Duties and Responsibilities:
1. To provide all forms of Joinery duties and tasks in which you are competent within the 
University Estate possessing a least five years trade experience. Working with the team 
across various other construction trades.
2. To be responsible for day-to-day breakdown and reactive maintenance. 
3. To participate in the Maintenance call out rota team.
4. To be responsible for working to and delivering cyclical maintenance works ensuring 
certain activities are carried out as per the PPM regime.
5. To manage the fire door programme focussing on the Inspection, maintenance (ART 
accepted repair techniques) and repair to achieve a compliant campus. This will involve 
a good theoretical knowledge of the standards and regulations.
6. To be responsible for the Fire door dashboard, upkeep and maintenance of the system. 
To provide information on defects and repair (analysing reports), accepted repair 
techniques and input for Projects.
7. To maintain Fire door records on CAFM and in line with the Fire Safety Regulations
(2023). Records must be kept.
8. Identify hazards, defects and the need for adjustment or repair; to ensure compliance 
with agreed codes, law, working practices and health and safety whilst carrying out your
duties.
9. To provide support and guidance to Contractors engaged in Fire door campus works and 
act as a focal point ensuring a fully compliant Fire door install is delivered to the Estate.
10. To manage quantities required to complete each task and manage material stocks and 
ordering process.
11. To be responsible for ensuring all tools and equipment are maintained in good working 
order and ready for use including power tools within the Estate.
12. To ensure all University fixtures, fittings, furniture, doors, locks, flooring, and other 
Joinery items are efficiently maintained, repaired, constructed or replaced, working 
closely with Estates, Facilities Managers and Estates Team leader to achieve. 
13. To ensure works delivered in compliance with documented risk assessments and Method 
statements, and responsible for the production and review of role specific risk 
assessments.
Joiner (Ref: 0021E) July 2023
14. To be responsible for a high standard of conduct always working in a safe and 
professional manner reporting any health and safety related issues to the Estates Team 
leader immediately.
15. To be responsible for working to and delivering all works and repairs in a manner that 
ensure VFM and quality finishes are implemented and maintained.
16. To assist the team and organisation with general duties over and above your core skills. 
Promote, develop and expand the business of our organisation generally meeting set 
targets.
17. To aid and advise the other members of the University Estates & Facilities staff including 
porters and grounds staff as required.
18. To adhere to all organisation policies and procedures.
19. To be responsible for continued professional development ensuring the post holder is 
conversant and aware of current regulations, legislation, and approved industry 
standards to their own job role. You will have a basic awareness of Asbestos, CDM, 
health and safety regulations.
20. To undertake small projects as reasonably required of the job role advise all Estates 
teams to deliver solutions, cost reductions to all joinery works on campus.
General Duties:
21. To ensure the use of data complies with current regulations, particularly those relating to 
GDPR.
22. To comply with all health, safety and wellbeing policies and procedures at all times and to 
take responsibility for promoting and safeguarding the welfare and protection of others. 
23. To advocate, promote and advance equity and social justice within your work.
24. To carry out other duties, commensurate with the grade of the post, as may reasonably be
directed by your line manager after due consultation


"""
predict_new_job_description(new_job_desc)
# Out:
# Available columns: ['code', 'job description', 'label']
# Labeled Data:
#      code                                    job description       label  \
# 0    1374  Provide support and guidance to Contractors en...  Response B
# 1    1374  Maintain Fire door records on CAFM and in line...  Response B
# 2    1374  To aid and advise other members of the Univers...  Response B
# 3    1391  Advise on accessibility in the context of web ...  Response A
# 4    1391  Gather user requirements and perform user test...  Response A
# ..    ...                                                ...         ...
# 454  1395  Handle a personal caseload appropriate to hour...  Response B
# 455  1395  Engage with technology in the delivery of coun...  Response B
# 456  1395  Assess risk and take appropriate action where ...  Response B
# 457  1395  Liaise with other Counsellors regarding ongoin...  Response B
# 458  1395  Work with colleagues involved in the welfare a...  Response B
#
# ...

# %%
# Example usage with a new job description snippet
new_job_desc = """




"""
predict_new_job_description(new_job_desc)
# Out:
# Predicted labels for the new job description:
# Q1_label: A
# Q2_label: A
# Q3_label: C
# Q4_label: A
# Q5_label: B
# Q6_label: A
